# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
from einops import rearrange
from PIL import Image
from tqdm import tqdm
import json
import time
from pathlib import Path
from sklearn import linear_model
import mediapy as media

# %%
session_dir = 'baselines/session_b6ca302c_final_curr'

# %%
# !dir -lt baselines
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F2C8-427E
#
#  Directory of C:\Users\dolson\Documents\GitHub\CSCE642PokemonRedDDPG
#
#
#  Directory of C:\Users\dolson\Documents\GitHub\CSCE642PokemonRedDDPG\baselines
#
# 12/02/2024  07:58 PM    <DIR>          .
# 12/02/2024  07:58 PM    <DIR>          ..
# 11/20/2024  03:42 PM                 5 agent_enabled.txt
# 12/02/2024  07:58 PM             1,080 CSCE642PokemonRedDDPG - Shortcut (2).lnk
# 11/26/2024  10:46 PM             1,080 CSCE642PokemonRedDDPG - Shortcut.lnk
# 11/26/2024  11:10 PM             8,289 DDPG.py
# 11/20/2024  03:42 PM                54 delete_empty_imgs.txt
# 11/20/2024  03:42 PM    <DIR>          grid_renders
# 11/20/2024  03:42 PM    <DIR>          ray_exp
# 11/29/2024  06:24 PM            25,323 red_gym_env.py
# 11/20/2024  03:42 PM             2,943 render_all_needed_grids.py
# 11/20/2024  03:42 PM                84 render_all_needed_grids.sh
# 11/20/2024  03:42 PM               218 requirements-unfrozen.txt
# 11/20/2024  09:58 PM             1,822 requirements.txt
# 11/20/2024  03:42 PM             2,806 run_baseline_parallel.py
# 12/01/2024  05:33 PM             3,272 run_baseline_parallel_fast.py
# 12/01/2024  07:32 PM             2,436 run_pretrained_interactive.py
# 11/20/2024  03:42 PM             1,259 run_recorded_actions.py
# 11/20/2024  03:42 PM             2,643 saves_to_record.txt
# 11/27/2024  10:29 PM    <DIR>          session_09c01923
# 12/01/2024  08:24 PM    <DIR>          session_0ccadddd_first_decent_curr
# 11/29/2024  02:51 PM    <DIR>          session_0d65c085
# 11/28/2024  05:00 PM    <DIR>          session_1b2ceec0
# 11/28/2024  02:43 PM    <DIR>          session_233a38d8
# 11/27/2024  11:58 PM    <DIR>          session_2919966b
# 11/30/2024  04:16 PM    <DIR>          session_3c4b7c32
# 11/20/2024  03:42 PM    <DIR>          session_4da05e87_main_good
# 11/27/2024  10:37 PM    <DIR>          session_5541ad18
# 11/27/2024  11:08 PM    <DIR>          session_59b44e36
# 11/24/2024  05:36 PM    <DIR>          session_6375c947_baseline
# 11/20/2024  04:16 PM    <DIR>          session_6b4f56c2
# 11/20/2024  04:09 PM    <DIR>          session_6e66ebac
# 11/27/2024  11:09 PM    <DIR>          session_79c3c52a
# 11/28/2024  07:36 PM    <DIR>          session_7c3cfbfa
# 11/29/2024  06:18 PM    <DIR>          session_7eb2fedc
# 11/28/2024  04:16 PM    <DIR>          session_94008658
# 11/21/2024  01:47 PM    <DIR>          session_9a292539
# 11/25/2024  09:21 AM    <DIR>          session_ad71073b
# 11/20/2024  04:00 PM    <DIR>          session_b03ae791
# 12/02/2024  08:28 PM    <DIR>          session_b6ca302c_final_curr
# 11/27/2024  10:23 PM    <DIR>          session_ded182c5
# 11/28/2024  02:00 PM    <DIR>          session_e1e29107
# 11/28/2024  07:41 PM    <DIR>          session_e4c76872
# 11/24/2024  06:01 PM    <DIR>          session_f398623e
# 11/22/2024  03:29 PM    <DIR>          session_f3c6ec0e
# 11/20/2024  04:11 PM    <DIR>          session_f42cb26c
# 11/28/2024  05:37 PM    <DIR>          session_f88b97f6
# 11/20/2024  03:42 PM             3,167 tile_vids_to_grid.py
# 12/02/2024  07:26 PM         3,212,907 Visualizations_over_time.ipynb
# 11/29/2024  06:25 PM    <DIR>          __pycache__
#               17 File(s)      3,269,388 bytes
#               33 Dir(s)  427,325,546,496 bytes free
# File Not Found

# %%
def load_run_data(run_path):
    run_lists = []
    for p in Path(run_path).glob('all_runs_*.json'):
        with open(p, 'r') as f:
            run_lists.append(json.load(f))
    all_runs = [val for tup in zip(*run_lists) for val in tup]
    print(f'runs loaded: {len(all_runs)}')
    return all_runs

# %%
def plot_runs(
    all_runs, use_keys=None, 
    plot_fit=False, plot_line=False, 
    start=0, group_runs=1,
    agg_func=np.mean):
    
    all_runs = all_runs[start:]
    x = np.arange(len(all_runs)//group_runs)
    
    def add_plot(y, name, alpha, size, plot_line, plot_fit):
        plt.scatter(x, y, alpha=alpha, s=size, label=name)
        if plot_line:
            plt.plot(x, y, alpha=alpha, label=name)
        if plot_fit:
            regr = linear_model.LinearRegression()
            # Optimize linear model
            regr.fit(x.reshape(-1, 1), y.reshape(-1, 1))

            # Make predictions using the testing set
            lin_y = regr.predict(x.reshape(-1, 1))
            plt.plot(x, lin_y, linewidth=3)
    
    # convert list of dictionaries to dictionary of lists
    metrics = {m: [run[m] for run in all_runs] for m in all_runs[0].keys()}
    metrics['total'] = [sum([v for _,v in run.items()]) for run in all_runs]
    if group_runs:
        for m, dat in metrics.items():
            metrics[m] = agg_func(np.array(dat).reshape(-1, group_runs), 1)
    available_keys = metrics.keys()
    print(f'available metrics: {list(available_keys)}')
    if use_keys is None:
        use_keys = available_keys
    
    ## TODO subplot for each metric ## 
    NUM_COLORS = len(use_keys)
    cm = plt.get_cmap('Dark2')
    cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
    scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
    fig = plt.figure(figsize = (12, 8))

    ax = fig.add_subplot(111)
    ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

    for i, m in enumerate(use_keys):
        add_plot(
            np.array(metrics[m]), m, 1.0, 3.0, plot_line, plot_fit
        )

    plt.title('Reward over runs PPO')
    plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
    plt.show()

# %%
def get_latest_grid(pth):
    imgs = np.array([np.array(Image.open(p)) for p in Path(pth).glob('curframe*.jpeg')])
    grid = rearrange(imgs, '(h2 w2) h w c -> (h2 h) (w2 w) c', w2=4)
    return grid

# %%
get_im_func = lambda: get_latest_grid(session_dir)

with media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:
    for i in range(500):
        wr.add_image(get_im_func())
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[170], line 6
#       4 for i in range(500):
#       5     wr.add_image(get_im_func())
# ----> 6     time.sleep(1)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (32, 32))
plt.imshow(get_latest_grid(session_dir))

# %%
(29556736 - 25952256) / (1024*16*44)
# Out:
# 5.0

# %%
plot_runs(
    load_run_data(session_dir),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=44*0,
    group_runs=80,
    agg_func=np.mean
)
# Out:
# runs loaded: 384
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 plot_runs(
#       2     load_run_data(session_dir),
#       3     use_keys=None,
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     start=44*0,
#       7     group_runs=80,
#       8     agg_func=np.mean
#       9 )
#
# Cell In[168], line 28, in plot_runs(all_runs, use_keys, plot_fit, plot_line, start, group_runs, agg_func)
#      26 if group_runs:
#      27     for m, dat in metrics.items():
# ---> 28         metrics[m] = agg_func(np.array(dat).reshape(-1, group_runs), 1)
#      29 available_keys = metrics.keys()
#      30 print(f'available metrics: {list(available_keys)}')
#
# ValueError: cannot reshape array of size 384 into shape (80)

# %%
plot_runs(
    load_run_data(session_dir),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=24,
    agg_func=np.mean
)
# Out:
# runs loaded: 384
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data(session_dir),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 384
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data(session_dir),
    use_keys=['level'],
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 384
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data(session_dir),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 80
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %% [markdown]
# ## generate moving histograms!

# %%
len(load_run_data(session_dir))
# Out:
# runs loaded: 384
# 384

# %%
def chunks(data, n):
    n = max(1, n)
    return [data[i:i+n] for i in range(0, len(data), n)]

# %%
full_dat = load_run_data(session_dir)
for run in full_dat:
    run["total"] = sum(value for value in run.values())
full_dat_chunks = chunks(full_dat, 44)
# Out:
# runs loaded: 384

# %%
full_dat[0]
# Out:
# {'event': 0,
#  'level': 12,
#  'heal': 1.333333333333333,
#  'op_lvl': 0.0,
#  'dead': -0.4,
#  'badge': 0,
#  'explore': 92.64,
#  'total': 105.57333333333334}

# %%
def histo_plot(axis, stat, dat_chunks, version, compare_count):
    
    test_dat = np.array([run[stat] for run in dat_chunks[version]])
    # the histogram of the data
    n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
    
    for i in range(compare_count):
        comp_version = max(version - 1 - i, 0)
        compare_dat = np.array([run[stat] for run in dat_chunks[comp_version]])
        n, bins, patches = axis.hist(compare_dat, 10, density=False, facecolor="grey", alpha=0.2*0.25**i)

    axis.set(xlabel=f"{stat}")
    #axis.ylabel()
    # only use this title over all plots
    #axis.title()
    #plt.xlim(40, 160)
    #plt.ylim(0, 0.03)
    #axis.grid(True)
    #plt.show()

# %%
def plot_all(dat_chunks, version, compare_count):
    fig, axs = plt.subplots(2, 4, figsize=(16, 9), dpi=120)
    #plt.subplots_adjust(bottom=0.0, right=0.8, top=0.9)
    fig.suptitle(f"Version {version} Rewards")
    for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
        histo_plot(ax, stat, dat_chunks, version, compare_count)
    return fig

# %%
plot_all(chunks(full_dat, 44), 10, 5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 plot_all(chunks(full_dat, 44), 10, 5)
#
# Cell In[113], line 6, in plot_all(dat_chunks, version, compare_count)
#       4 fig.suptitle(f"Version {version} Rewards")
#       5 for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
# ----> 6     histo_plot(ax, stat, dat_chunks, version, compare_count)
#       7 return fig
#
# Cell In[112], line 3, in histo_plot(axis, stat, dat_chunks, version, compare_count)
#       1 def histo_plot(axis, stat, dat_chunks, version, compare_count):
# ----> 3     test_dat = np.array([run[stat] for run in dat_chunks[version]])
#       4     # the histogram of the data
#       5     n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
#
# IndexError: list index out of range

# %%
#histo_plot("level", )

# %%
with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
    for i in tqdm(range(80)):
        #with plt.style.context('Solarize_Light2'):
        fig = plot_all(full_dat_chunks, i, 5)

        fig.canvas.draw()
        #plt.show()
        data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
        data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
        wr.add_image(data)
        plt.close()
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]C:\Users\dolson\AppData\Local\Temp\ipykernel_14576\3255727061.py:8: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
#  38%|███▊      | 30/80 [00:36<01:01,  1.22s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[85], line 4
#       1 with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
#       2     for i in tqdm(range(80)):
#       3         #with plt.style.context('Solarize_Light2'):
# ----> 4         fig = plot_all(full_dat_chunks, i, 5)
#       6         fig.canvas.draw()
#       7         #plt.show()
#
# Cell In[82], line 6, in plot_all(dat_chunks, version, compare_count)
#       4 fig.suptitle(f"Version {version} Rewards")
#       5 for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
# ----> 6     histo_plot(ax, stat, dat_chunks, version, compare_count)
#       7 return fig
#
# Cell In[81], line 3, in histo_plot(axis, stat, dat_chunks, version, compare_count)
#       1 def histo_plot(axis, stat, dat_chunks, version, compare_count):
# ----> 3     test_dat = np.array([run[stat] for run in dat_chunks[version]])
#       4     # the histogram of the data
#       5     n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
#
# IndexError: list index out of range
